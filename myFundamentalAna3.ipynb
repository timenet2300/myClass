# %% [markdown]
# <a href="https://colab.research.google.com/github/timenet2300/myArchive1/blob/main/myFundamentalAna.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
勺

# %% [markdown]
# # 找出公司基本面的財務資料

# %%
# !pip install FundamentalAnalysis
# Out:
# ...
#   Created wheel for FundamentalAnalysis: filename=FundamentalAnalysis-0.2.6-cp36-none-any.whl size=9735 sha256=49d6fd37b5d4afa43b3ad4d308b5281374de2c7fad032f2baeb7fd4f314b8be9
#   Stored in directory: /root/.cache/pip/wheels/d2/09/b7/cae273de32fdaa5dae02f207e91294b40fd1cba026448116a3
# Successfully built FundamentalAnalysis
# ...

# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Feb 14 01:35:31 2021

@author: Administrator
"""


import FundamentalAnalysis as fa

ticker = "AAPL"
api_key = "069b292a8da47a7d94698f8ce2bd3f6e"

# %%
# Show the available companies
companies = fa.available_companies(api_key)
type(companies)
companies.shape
companies.columns
#companies.name.AAPL
#companies['name']['AAPL']
#list(companies)
# Out:
# Index(['name', 'price', 'exchange'], dtype='object')

# %%
companies['name'].AAPL
companies['price'].AAPL
companies['exchange'].AAPL

#companies['SPY']['price']
# Collect general company information
# Out:
# 'Nasdaq Global Select'

# %%
profile = fa.profile(ticker, api_key)
# Collect recent company quotes

# %%
quotes = fa.quote(ticker, api_key)
quotes
# Out:
#                                                  0
# symbol                                        AAPL
# name                                    Apple Inc.
# price                                       135.37
# changesPercentage                             0.18
# change                                        0.24
# dayLow                                     133.692
# dayHigh                                     135.51
# yearHigh                                    145.09
# yearLow                                    53.1525
# marketCap                               2.2726e+12
# priceAvg50                                 133.991
# priceAvg200                                121.247
# volume                                    60145130
# avgVolume                                102483022
# exchange                                    NASDAQ
# open                                        134.35
# previousClose                               135.13
# ...

# %%
# Collect market cap and enterprise value
entreprise_value = fa.enterprise(ticker, api_key)
entreprise_value

# %%
# Obtain DCFs over time
dcf_annually = fa.discounted_cash_flow(ticker, api_key, period="annual")
dcf_quarterly = fa.discounted_cash_flow(ticker, api_key, period="quarter")

# Collect the Balance Sheet statements
balance_sheet_annually = fa.balance_sheet_statement(ticker, api_key, period="annual")
balance_sheet_quarterly = fa.balance_sheet_statement(ticker, api_key, period="quarter")

# %%
# Collect the Income Statements
income_statement_annually = fa.income_statement(ticker, api_key, period="annual")
income_statement_quarterly = fa.income_statement(ticker, api_key, period="quarter")

# %%
# Collect the Cash Flow Statements
cash_flow_statement_annually = fa.cash_flow_statement(ticker, api_key, period="annual")
cash_flow_statement_quarterly = fa.cash_flow_statement(ticker, api_key, period="quarter")

# %%
# Show Key Metrics
key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual")
key_metrics_quarterly = fa.key_metrics(ticker, api_key, period="quarter")
key_metrics_quarterly

# %%
# Show a large set of in-depth ratios
financial_ratios_annually = fa.financial_ratios(ticker, api_key, period="annual")
financial_ratios_quarterly = fa.financial_ratios(ticker, api_key, period="quarter")
# Show recommendations of Analysts
ratings = fa.rating(ticker, api_key)
financial_ratios_quarterly
# Out:
#                                        2020-12  ...     1989-09
# currentRatio                          1.163003  ...    2.563128
# quickRatio                            0.784313  ...    1.789944
# cashRatio                             0.271759  ...    0.489385
# daysOfSalesOutstanding               88.764840  ...  209.136561
# daysOfInventoryOutstanding            6.669100  ...   63.146233
# operatingCycle                       28.556321  ...  114.714152
# daysOfPayablesOutstanding            85.621433  ...   44.401773
# cashConversionCycle                 -57.065112  ...   70.312380
# grossProfitMargin                     0.397778  ...    0.510116
# operatingProfitMargin                 0.300918  ...    0.124277
# pretaxProfitMargin                    0.301322  ...    0.190751
# netProfitMargin                       0.258034  ...    0.116329
# effectiveTaxRate                      0.143661  ...    0.390152
# returnOnAssets                        0.081216  ...    0.058673
# ...

# %%
# Show the growth of the company
growth_annually = fa.financial_statement_growth(ticker, api_key, period="annual")
growth_quarterly = fa.financial_statement_growth(ticker, api_key, period="quarter")

# %%
# Download general stock data
stock_data = fa.stock_data(ticker, period="ytd", interval="1d")

# Download detailed stock data
stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="2000-01-01", end="2020-01-01")
stock_data_detailed

# %% [markdown]
# # 找出公司股市的Beta

# %%
# !pip install yahoofinancials
# Out:
# ...
#   Created wheel for yahoofinancials: filename=yahoofinancials-1.6-cp36-none-any.whl size=15192 sha256=ebd5280068bac67b081e9d94a924be6c04169fd1e273aa1468d89c5cffd9b092
#   Stored in directory: /root/.cache/pip/wheels/d9/7e/cf/4977a8572d5247242a4b13018d1d36923024ba84236e0d28bc
# Successfully built yahoofinancials
# ...

# %%
import pandas as pd
from yahoofinancials import YahooFinancials
#one stock
#yahoo_financials = YahooFinancials('^GSPC')
yahoo_financials = YahooFinancials('AAPL')

# %%
#data3 = yahoo_financials.get_historical_price_data(start_date='2013-01-01',                                        
#                                                  end_date='2021-01-22',
#                                                time_intervals='daily')
data = yahoo_financials.get_historical_price_data(start_date='2013-01-01', 
                                                  end_date='2021-01-22', 
                                                  time_interval='daily')
#tsla_df = pd.DataFrame(data['TSLA']['prices'])
#tsla_df = tsla_df.drop('date', axis=1).set_index('formatted_date')

#tsla_df.head()

# %%
data2=yahoo_financials.get_key_statistics_data()
#yahoo_financials.get_summary_data()
# Out:
# dict_keys(['AAPL'])
# ...

# %%
#Get data method 1
#確認 data type
type(data2) # level in level
#找出data keys
print(data2.keys())
print(data2['AAPL'].keys())
#用data keys 找出beta
data2['AAPL']['beta']
#data2

# %%
#Get data method2
list(data2)
# Out:
# <function dict.values>

# %%
list(data2['AAPL'])

# %%
Applebeta=data2['AAPL']['beta']
Applebeta
# Out:
# 1.267876

# %% [markdown]
# # 畫岀5家公司財務資料比較圖

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

objects = ('AAPL', 'FB', 'MSFT', 'GOOGL', 'AMZN')
y_pos = np.arange(len(objects))
performance = [Applebeta,8,6,3,2]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)
plt.ylabel('Beta value')
plt.title('5 Big Techs Marekt Beta')

plt.show()
# debt/asset ratio; P/E ratio; Payout ratio; Current ratio
